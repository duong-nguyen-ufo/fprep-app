# %%
import os 
import openai
from openai import OpenAI
import getpass
import pandas as pd

# %%
# Authenticate OpenAI API
key = getpass.getpass('Paste your OpenAI API key: ')
os.environ['OPENAI_API_KEY'] = key
openai.api_key = os.getenv('OPENAI_API_KEY')
# Out:
# Paste your OpenAI API key:  ········

# %%
# Get user's name
user_name = input('What is your name?')
# Out:
# What is your name? ufo

# %%
# User's kitchen setup 
stove_burner = input('How many stove burners do you have?')
oven_rack = input('How many oven racks do you have?')
sous_vide_bag = input('How many sous vide bags do you have?')
large_pan = input('How many large size pans do you have?')
medium_pan = input('How many medium size pans do you have?')
small_pan = input('How many small size pans do you have?')
large_pot = input('How many large size pots do you have?')
medium_pot = input('How many medium size pots do you have?')
small_pot = input('How many small size pots do you have?')
food_processor = input('How many food processors do you have?')
blender_cup = input('How many blender cups do you have?')
crock_pot = input('How many crock pots do you have?')
rice_cooker = input('How many rice cookers do you have?')
thermometer = input('How many thermometers do you have?')
# Out:
# How many stove burners do you have? 3
# How many oven racks do you have? 3
# How many sous vide bags do you have? 4
# How many large size pans do you have? 1
# How many medium size pans do you have? 2
# How many small size pans do you have? 0
# How many large size pots do you have? 2
# How many medium size pots do you have? 2
# How many small size pots do you have? 2
# How many food processors do you have? 1
# How many blender cups do you have? 2
# How many crock pots do you have? 1
# How many rice cookers do you have? 1
# How many thermometers do you have? 2

# %%
# Append new user profile to store in dataframe
df = pd.DataFrame(columns=['user_name', 'stove_burner', 'oven_rack', 'sous_vide_bag', 'large_pan', 'medium_pan', 
                          'small_pan', 'large_pot', 'medium_pot', 'small_pot', 'food_processor', 'blender_cup', 'crock_pot', 'thermometer'])
user_profile = [user_name, stove_burner, oven_rack, sous_vide_bag, large_pan, medium_pan, small_pan, large_pot, medium_pot, small_pot, food_processor, blender_cup, crock_pot, thermometer]

user_profile_series = pd.Series(dict(zip(df.columns, user_profile)))
df = df._append(user_profile_series, ignore_index=True)              
df
# Out:
#   user_name stove_burner oven_rack sous_vide_bag large_pan medium_pan  \
# 0       ufo            3         3             4         1          2
#
#   small_pan large_pot medium_pot small_pot food_processor blender_cup  \
# 0         0         2          2         2              1           2
#
#   crock_pot thermometer
# 0         1           2

# %%
# User's food and cooking preferences

style = input('What style do you want your recipes to be? Simple and minimal / Complex with layers of flavors / Balance - not too simple but not too complex')
calories = input('How many calories do you want for the total of all three meals per day?')
additional_preference = input('Any additional preference? Such as the type of cuisine, the use of ingredients or cooking methods?')
temp_unit = input('What is your temperature measure unit?')
liquid_unit = input('What is your liquid measure unit?')
mass_unit = input('What is your mass measure unit?')
# Out:
# What style do you want your recipes to be? Simple and minimal / Complex with layers of flavors / Balance - not too simple but not too complex simple and minimal
# How many calories do you want for the total of all three meals per day? 2000
# Any additional preference? Such as the type of cuisine, the use of ingredients or cooking methods? use very little oil and sugar. keep food as lean as possible. prefer steam, sous vide, oven bake, crock pot over frying.
# What is your temperature measure unit? celcius
# What is your liquid measure unit? ml and liter
# What is your mass measure unit? kg and gram

# %%
# User's needs for recipes 
existing_ingredients = input('Are there any ingredients that you already have and want to incoroporate into the recipes if possible?')

days = input('How many days do you want to cook for?')
breakfast = input('What do you want to have for breakfast?')
lunch = input('What do you want to have for lunch?')
dinner = input('What do you want to have for dinner?')
# Out:
# Are there any ingredients that you already have and want to incoroporate into the recipes if possible? a can of chickpeas, pickles, and uncooked cashew nuts
# How many days do you want to cook for? 5
# What do you want to have for breakfast? unsure, use some or all of the existing ingredients if possible
# What do you want to have for lunch? chicken breast sandwich
# What do you want to have for dinner? brown rice, pork, vegetables

# %%
# Call OpenAI API
client = OpenAI()

# System prompt and model
system_prompt = '''You are an experienced chef. You have many experiences in cooking healthy dishes and cooking multiple dishes simultaneously in a very efficient, methodological way.'''
model = 'gpt-4o-mini'

# %%
# Generate recipes and grocery list prompt

recipe_user_prompt = f'''
Please help write a meal plan and grocery list tailored to my needs.

Step 1: Understand all the information that you need to write a cooking plan for my  needs.
- My style of cooking is {style}.
- I want to cook for {days} for the next week.
- I need all meals combined to have {calories} kcal per day.
- For breakfast, I want {breakfast}. 
- For lunch, I want {lunch}.
- For dinner, I want {dinner}.
- My preference for the food is {additional_preference}.
- The existing ingredients that I want to incorporate into the recipes, if possible, are {existing_ingredients}.
- My measure units for temperature, liquid, and mass, respectively, are: {temp_unit}, {liquid_unit}, {mass_unit}
- For my cooking equipment, besides the basic equipment like knives, spatulas, spoons, forks, mixing bowls, measuring cups, etc., here is the list of the key equipment I have:
  + {stove_burner} stove burners 
  + {oven_rack} oven racks 
  + {sous_vide_bag} sous vide bags 
  + {large_pan} large pans 
  + {medium_pan} medium pans
  + {small_pan} small pans
  + {large_pot} large pots
  + {medium_pot} medium pots
  + {small_pot} small pots
  + {food_processor} food processors
  + {blender} blender cups
  + {crock_pot} crock pots
  + {rice_cooker} rice cookers
  + {thermometer} thermometers

Step 2: Generate the recipes for each meal given in Step 1. For each meal: 
- Give the meal a name
- State the cooking method
- Estimate the calories for this meal for one day
- Write the recipe. Ensure that the recipe meets the needs in Step 1 and use the cooking equipment only listed in Step 1. 
  -- Ingredients: List the ingredients. All ingredients must have the amount needed for the recipe. 
  -- Equipment: List the equipment needed for the recipe
  -- Instructions: List the steps to cook the recipe

Step 3: Combine the ingredient lists from the three meals into one list. This will be my grocery list. 
- This grocery list is split into two sections: 
  -- 1. Ingredients I already have
  -- 2. Ingredients I need to buy.  All ingredients must have the amount needed for the recipes. 
- For each ingredient, state the amount needed for that ingredient. If two recipes share the same ingredient, list how much of that ingredient is needed for each meal. For example: "Mixed greens: 5 cups for breakfast, 5 cups for dinner". 

Step 4: Export the output in the format below. Ensure that the output does not include any XML tags. 
**Recipes**
Breakfast: (recipe in Step 2 for {breakfast})
Lunch: (recipe in Step 2 for {lunch})
Dinner: (recipe in Step 2 for {dinner})

**Grocery list**
(summarized list of ingredients in Step 3)
'''

# %%
recipe_response = client.chat.completions.create(
    model = model,
    messages = [
    {'role': 'system', 'content': system_prompt},
    {'role': 'user', 'content': recipe_user_prompt}
    ],
    temperature = 0.1
).choices[0].message.content

print(recipe_response)
# Out:
# **Recipes**
#
# **Breakfast: Chickpea and Cashew Smoothie Bowl**
# - **Cooking Method:** Blending
# - **Estimated Calories:** 400 kcal per serving
#
# **Ingredients:**
# - 1 can chickpeas (drained and rinsed) - 400g
# - 100g uncooked cashew nuts (soaked in water for 2 hours)
# - 500ml water or unsweetened almond milk
# - 1 banana (for sweetness) - 100g
# - 1 tsp cinnamon (optional)
#
# **Equipment:**
# - Blender
# - Mixing bowl
#
# **Instructions:**
# 1. Drain and rinse the chickpeas and place them in the blender.
# 2. Add the soaked cashew nuts, water or almond milk, banana, and cinnamon to the blender.
# 3. Blend until smooth and creamy.
# 4. Pour into bowls and top with additional sliced banana or nuts if desired.
#
# ---
#
# **Lunch: Grilled Chicken Breast Sandwich**
# - **Cooking Method:** Grilling (or baking)
# - **Estimated Calories:** 600 kcal per serving
#
# **Ingredients:**
# - 5 chicken breasts (about 150g each) - 750g
# - 5 whole grain sandwich rolls - 5 rolls
# - 200g lettuce (for topping)
# - 100g pickles (for topping)
# - Salt and pepper to taste
# - 1 tsp garlic powder (optional)
#
# **Equipment:**
# - Grill or oven
# - Large pan (for grilling)
# - Tongs
#
# **Instructions:**
# 1. Preheat the grill or oven to 200°C.
# 2. Season the chicken breasts with salt, pepper, and garlic powder.
# 3. Grill or bake the chicken breasts for about 20-25 minutes or until cooked through (internal temperature of 75°C).
# 4. Slice the chicken breasts and assemble the sandwiches with lettuce and pickles in the whole grain rolls.
#
# ---
#
# **Dinner: Brown Rice with Pork and Steamed Vegetables**
# - **Cooking Method:** Steaming and cooking rice
# - **Estimated Calories:** 1000 kcal per serving
#
# **Ingredients:**
# - 500g brown rice
# - 750g pork tenderloin (lean cut)
# - 500g mixed vegetables (broccoli, carrots, bell peppers)
# - 1 tbsp soy sauce (optional, for flavor)
# - Salt and pepper to taste
#
# **Equipment:**
# - Rice cooker
# - Large pot (for steaming vegetables)
# - Thermometer
#
# **Instructions:**
# 1. Rinse the brown rice under cold water and cook it in the rice cooker according to the manufacturer's instructions.
# 2. Season the pork tenderloin with salt and pepper.
# 3. Preheat the oven to 200°C. Place the pork in a baking dish and bake for about 25-30 minutes or until the internal temperature reaches 70°C.
# 4. While the pork is cooking, fill a large pot with water and bring it to a boil. Place the mixed vegetables in a steamer basket and steam for about 5-7 minutes until tender.
# 5. Slice the pork and serve it over brown rice with steamed vegetables on the side. Drizzle with soy sauce if desired.
#
# ---
#
# **Grocery list**
#
# **Ingredients I already have:**
# - Chickpeas: 400g for breakfast
# - Pickles: 100g for lunch
# - Uncooked cashew nuts: 100g for breakfast
#
# **Ingredients I need to buy:**
# - Chicken breasts: 750g for lunch
# - Whole grain sandwich rolls: 5 rolls for lunch
# - Lettuce: 200g for lunch
# - Banana: 100g for breakfast
# - Brown rice: 500g for dinner
# - Pork tenderloin: 750g for dinner
# - Mixed vegetables: 500g for dinner
# - Soy sauce: 1 tbsp for dinner (optional)
# - Salt and pepper: to taste for all meals
# - Garlic powder: 1 tsp for lunch (optional)
# - Cinnamon: 1 tsp for breakfast (optional)
# - Water or unsweetened almond milk: 500ml for breakfast

# %%
want_to_update = input('Do you want to update the recipes?')
# Out:
# Do you want to update the recipes? yes

# %%
if want_to_update.lower() == 'no':
    recipe_response = recipe_response
    print("Cool! Let's move on to the cooking plan.")
    
if want_to_update.lower() == 'yes':
    update_questions = list()
    update_bot_responses = list()
    update_messages = list()

    update_messages.append({'role': 'system', 'content': system_prompt})
    update_messages.append({'role': 'assistant', 'content': recipe_response + 'Ensure that you keep the current output format as above for every time you update the recipe'})

    while True: # create an infinite loop of dialog until user exits
        current_question = input('Which parts of the recipes do you want to adjust?')
        
        if current_question.lower() in ['exit', 'quit', 'nothing else']:
            print("Cool! Let's move on to the cooking plan.")
            recipe_response = update_bot_responses[-1]
            # time.sleep(2) # wait for two seconds before ending so it's better UX
            break

        if current_question == '': #if user just hits Enter without a question, the conversation still continues
            continue 

        update_messages.append({'role': 'user', 'content': current_question})
        update_questions.append(current_question)
    
        recipe_update_response = client.chat.completions.create(
                                    model = model,
                                    messages = update_messages,
                                    temperature = 0.1
        )
      
        current_response = recipe_update_response.choices[0].message.content
        print(f'{current_response}')

        update_bot_responses.append(current_response)
        update_messages.append({'role': 'assistant', 'content': current_response + 'Ensure that you keep the current output format as above for every time you update the recipe'})
        
        print('\n' + '-'*50 + '\n')
# Out:
# Which parts of the recipes do you want to adjust? add baked tofu to breakfast and sous vide chicken for lunch instead
# **Recipes**
#
# **Breakfast: Chickpea, Cashew, and Baked Tofu Smoothie Bowl**
# - **Cooking Method:** Blending and baking
# - **Estimated Calories:** 500 kcal per serving
#
# **Ingredients:**
# - 1 can chickpeas (drained and rinsed) - 400g
# - 100g uncooked cashew nuts (soaked in water for 2 hours)
# - 500ml water or unsweetened almond milk
# - 1 banana (for sweetness) - 100g
# - 1 tsp cinnamon (optional)
# - 200g firm tofu (cubed)
# - 1 tbsp olive oil
# - Salt and pepper to taste
#
# **Equipment:**
# - Blender
# - Baking sheet
# - Mixing bowl
#
# **Instructions:**
# 1. Preheat the oven to 200°C.
# 2. Toss the cubed tofu with olive oil, salt, and pepper, and spread it on a baking sheet. Bake for 20-25 minutes until golden and crispy.
# 3. Drain and rinse the chickpeas and place them in the blender.
# 4. Add the soaked cashew nuts, water or almond milk, banana, and cinnamon to the blender.
# 5. Blend until smooth and creamy.
# 6. Once the tofu is done, add it to the smoothie bowl or serve it on top. Pour the smoothie into bowls and top with additional sliced banana or nuts if desired.
#
# ---
#
# **Lunch: Sous Vide Chicken Breast Sandwich**
# - **Cooking Method:** Sous vide
# - **Estimated Calories:** 600 kcal per serving
#
# **Ingredients:**
# - 5 chicken breasts (about 150g each) - 750g
# - 5 whole grain sandwich rolls - 5 rolls
# - 200g lettuce (for topping)
# - 100g pickles (for topping)
# - Salt and pepper to taste
# - 1 tsp garlic powder (optional)
#
# **Equipment:**
# - Sous vide machine
# - Vacuum-seal bags or zip-top bags
# - Large pan (for searing)
#
# **Instructions:**
# 1. Preheat the sous vide water bath to 65°C.
# 2. Season the chicken breasts with salt, pepper, and garlic powder. Place them in vacuum-seal bags or zip-top bags, removing as much air as possible.
# 3. Submerge the bags in the water bath and cook for 1.5 to 2 hours.
# 4. Once cooked, remove the chicken from the bags and pat dry. Sear in a hot pan for 1-2 minutes on each side for a golden crust.
# 5. Slice the chicken breasts and assemble the sandwiches with lettuce and pickles in the whole grain rolls.
#
# ---
#
# **Dinner: Brown Rice with Pork and Steamed Vegetables**
# - **Cooking Method:** Steaming and cooking rice
# - **Estimated Calories:** 1000 kcal per serving
#
# **Ingredients:**
# - 500g brown rice
# - 750g pork tenderloin (lean cut)
# - 500g mixed vegetables (broccoli, carrots, bell peppers)
# - 1 tbsp soy sauce (optional, for flavor)
# - Salt and pepper to taste
#
# **Equipment:**
# - Rice cooker
# - Large pot (for steaming vegetables)
# - Thermometer
#
# **Instructions:**
# 1. Rinse the brown rice under cold water and cook it in the rice cooker according to the manufacturer's instructions.
# 2. Season the pork tenderloin with salt and pepper.
# 3. Preheat the oven to 200°C. Place the pork in a baking dish and bake for about 25-30 minutes or until the internal temperature reaches 70°C.
# 4. While the pork is cooking, fill a large pot with water and bring it to a boil. Place the mixed vegetables in a steamer basket and steam for about 5-7 minutes until tender.
# 5. Slice the pork and serve it over brown rice with steamed vegetables on the side. Drizzle with soy sauce if desired.
#
# ---
#
# **Grocery list**
#
# **Ingredients I already have:**
# - Chickpeas: 400g for breakfast
# - Pickles: 100g for lunch
# - Uncooked cashew nuts: 100g for breakfast
# - Olive oil: for breakfast
#
# **Ingredients I need to buy:**
# - Firm tofu: 200g for breakfast
# - Chicken breasts: 750g for lunch
# - Whole grain sandwich rolls: 5 rolls for lunch
# - Lettuce: 200g for lunch
# - Banana: 100g for breakfast
# - Brown rice: 500g for dinner
# - Pork tenderloin: 750g for dinner
# - Mixed vegetables: 500g for dinner
# - Soy sauce: 1 tbsp for dinner (optional)
# - Salt and pepper: to taste for all meals
# - Garlic powder: 1 tsp for lunch (optional)
# - Cinnamon: 1 tsp for breakfast (optional)
# - Water or unsweetened almond milk: 500ml for breakfast
#
# --------------------------------------------------
# Which parts of the recipes do you want to adjust? exit
# Cool! Let's move on to the cooking plan.

# %%
print(recipe_response)
# Out:
# **Recipes**
#
# **Breakfast: Chickpea, Cashew, and Baked Tofu Smoothie Bowl**
# - **Cooking Method:** Blending and baking
# - **Estimated Calories:** 500 kcal per serving
#
# **Ingredients:**
# - 1 can chickpeas (drained and rinsed) - 400g
# - 100g uncooked cashew nuts (soaked in water for 2 hours)
# - 500ml water or unsweetened almond milk
# - 1 banana (for sweetness) - 100g
# - 1 tsp cinnamon (optional)
# - 200g firm tofu (cubed)
# - 1 tbsp olive oil
# - Salt and pepper to taste
#
# **Equipment:**
# - Blender
# - Baking sheet
# - Mixing bowl
#
# **Instructions:**
# 1. Preheat the oven to 200°C.
# 2. Toss the cubed tofu with olive oil, salt, and pepper, and spread it on a baking sheet. Bake for 20-25 minutes until golden and crispy.
# 3. Drain and rinse the chickpeas and place them in the blender.
# 4. Add the soaked cashew nuts, water or almond milk, banana, and cinnamon to the blender.
# 5. Blend until smooth and creamy.
# 6. Once the tofu is done, add it to the smoothie bowl or serve it on top. Pour the smoothie into bowls and top with additional sliced banana or nuts if desired.
#
# ---
#
# **Lunch: Sous Vide Chicken Breast Sandwich**
# - **Cooking Method:** Sous vide
# - **Estimated Calories:** 600 kcal per serving
#
# **Ingredients:**
# - 5 chicken breasts (about 150g each) - 750g
# - 5 whole grain sandwich rolls - 5 rolls
# - 200g lettuce (for topping)
# - 100g pickles (for topping)
# - Salt and pepper to taste
# - 1 tsp garlic powder (optional)
#
# **Equipment:**
# - Sous vide machine
# - Vacuum-seal bags or zip-top bags
# - Large pan (for searing)
#
# **Instructions:**
# 1. Preheat the sous vide water bath to 65°C.
# 2. Season the chicken breasts with salt, pepper, and garlic powder. Place them in vacuum-seal bags or zip-top bags, removing as much air as possible.
# 3. Submerge the bags in the water bath and cook for 1.5 to 2 hours.
# 4. Once cooked, remove the chicken from the bags and pat dry. Sear in a hot pan for 1-2 minutes on each side for a golden crust.
# 5. Slice the chicken breasts and assemble the sandwiches with lettuce and pickles in the whole grain rolls.
#
# ---
#
# **Dinner: Brown Rice with Pork and Steamed Vegetables**
# - **Cooking Method:** Steaming and cooking rice
# - **Estimated Calories:** 1000 kcal per serving
#
# **Ingredients:**
# - 500g brown rice
# - 750g pork tenderloin (lean cut)
# - 500g mixed vegetables (broccoli, carrots, bell peppers)
# - 1 tbsp soy sauce (optional, for flavor)
# - Salt and pepper to taste
#
# **Equipment:**
# - Rice cooker
# - Large pot (for steaming vegetables)
# - Thermometer
#
# **Instructions:**
# 1. Rinse the brown rice under cold water and cook it in the rice cooker according to the manufacturer's instructions.
# 2. Season the pork tenderloin with salt and pepper.
# 3. Preheat the oven to 200°C. Place the pork in a baking dish and bake for about 25-30 minutes or until the internal temperature reaches 70°C.
# 4. While the pork is cooking, fill a large pot with water and bring it to a boil. Place the mixed vegetables in a steamer basket and steam for about 5-7 minutes until tender.
# 5. Slice the pork and serve it over brown rice with steamed vegetables on the side. Drizzle with soy sauce if desired.
#
# ---
#
# **Grocery list**
#
# **Ingredients I already have:**
# - Chickpeas: 400g for breakfast
# - Pickles: 100g for lunch
# - Uncooked cashew nuts: 100g for breakfast
# - Olive oil: for breakfast
#
# **Ingredients I need to buy:**
# - Firm tofu: 200g for breakfast
# - Chicken breasts: 750g for lunch
# - Whole grain sandwich rolls: 5 rolls for lunch
# - Lettuce: 200g for lunch
# - Banana: 100g for breakfast
# - Brown rice: 500g for dinner
# - Pork tenderloin: 750g for dinner
# - Mixed vegetables: 500g for dinner
# - Soy sauce: 1 tbsp for dinner (optional)
# - Salt and pepper: to taste for all meals
# - Garlic powder: 1 tsp for lunch (optional)
# - Cinnamon: 1 tsp for breakfast (optional)
# - Water or unsweetened almond milk: 500ml for breakfast

# %%
# # User's update to the recipes if they want: ==> To update chat bot code below to get recipe update from user

# update_questions = list()
# update_bot_responses = list()
# update_messages = list()

# # system_prompt

# update_messages.append({'role': 'system', 'content': system_prompt})

# update_messages.append({'role': 'assistant', 'content': recipe_response})

# while True: # create an infinite loop of dialog until user exits
#     current_question = input('Is there any part of the recipes do you want adjust?') + 'Ensure that you keep the current output format.'
#     if current_question.lower() in ['exit', 'quit']:
#         print("Cool! Let's move on to the cooking plan.")
#         # recipe_response = recipe_response
#         time.sleep(2) # wait for two seconds before ending so it's better UX
#         break

#     if current_question == '': #if user just hits Enter without a question, the conversation still continues
#         continue 

#     update_messages.append({'role': 'user', 'content': current_question})
#     update_questions.append(current_question)

#     recipe_update_response = client.chat.completions.create(
#                                 model = model,
#                                 messages = update_messages,
#                                 temperature = 0.1
#     )

#     current_response = recipe_update_response.choices[0].message.content
#     print(f'{current_response}')

#     update_bot_responses.append(current_response)
#     update_messages.append({'role': 'assistant', 'content': current_response})

#     print('\n' + '-'*50 + '\n')  
#     # recipe_response = current_response

# %%
# print(bot_responses[-1])

# %%
# Generate cooking plan, step by step 

cooking_user_prompt = f'''
Please help write a cooking plan, step by step, that is tailored to my needs below.

Step 1: Understand all the information that you need to write a cooking plan for my  needs.
- I have very limited time, so I want to cook all three meals for all {days} days at once, then store the meals for the week. 
- The recipes I want to cook are the section **Recipes** in {recipe_response}
- For my cooking equipment, besides the basic equipment like knives, spatulas, spoons, forks, mixing bowls, measuring cups, etc., here is the list of the key equipment I have:
  + {stove_burner} stove burners 
  + {oven_rack} oven racks 
  + {sous_vide_bag} sous vide bags 
  + {large_pan} large pans 
  + {medium_pan} medium pans
  + {small_pan} small pans
  + {large_pot} large pots
  + {medium_pot} medium pots
  + {small_pot} small pots
  + {food_processor} food processors
  + {blender} blender cups
  + {crock_pot} crock pots
  + {thermometer} themometers

Step 2: Generate the cooking plan, step by step. The goal of the cooking plan is to make the cooking as efficient as possible with little waiting time.
The plan should meet the following criteria:
- Have very minimal in-cooking equipment washing time
- Utilize all the equipment as much as possible to prepare or cook multiple ingredients simultaneously. 
- Include the steps and time for washing produce and washing equipment, if any.
- Estimate the time taken for each step
- Because the food is cooked and stored for the week ahead, include the storing and packing step. 

The cooking plan should start from the minute 0 as the starting point of the cooking timeline, then add each step with the step's duration. 

Step 6: Export the output in the format below. Ensure that the output does not include any XML tags. 
**Total time**: (estimated total time)
**Steps**
- Minute: (start from 0). Duration: (time for this tep). Step name and instruction: (tasks needed to be done in this step)

Example:
**Total time**: 3 hours 35 minutes
**Steps**:
- Milestone: minute 0. Step: Preheat the oven to 200°C for the tofu and pork. Duration: 5 minutes. 
- Milestone: minute 1. Step: Measure all ingredients for each recipe and set them aside. Duration: 15 minutes. 
- Milestone: minute 16. Step: Wash and rinse all produce: chickpeas, letetuce, mixed vegetables. Duration: 10 minutes.
'''

# %%
cooking_response = client.chat.completions.create(
        model = model,
        messages = [
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': cooking_user_prompt}
        ],
        temperature = 0
).choices[0].message.content

print(cooking_response)
# Out:
# **Total time**: 3 hours 15 minutes
# **Steps**:
# - Milestone: minute 0. Step: Preheat the oven to 200°C for the tofu and pork. Duration: 5 minutes.
# - Milestone: minute 5. Step: Measure all ingredients for each recipe and set them aside. Duration: 15 minutes.
# - Milestone: minute 20. Step: Wash and rinse all produce: chickpeas, lettuce, and mixed vegetables. Duration: 10 minutes.
# - Milestone: minute 30. Step: Soak cashew nuts in water for 2 hours (this can be done while preparing other ingredients). Duration: 0 minutes (passive).
# - Milestone: minute 30. Step: Prepare tofu by cubing it and tossing it with olive oil, salt, and pepper. Duration: 10 minutes.
# - Milestone: minute 40. Step: Spread the cubed tofu on a baking sheet and place it in the preheated oven. Bake for 20-25 minutes until golden and crispy. Duration: 25 minutes (active time: 5 minutes).
# - Milestone: minute 40. Step: Season chicken breasts with salt, pepper, and garlic powder. Place them in vacuum-seal bags or zip-top bags. Duration: 10 minutes.
# - Milestone: minute 50. Step: Preheat the sous vide water bath to 65°C. Submerge the chicken bags in the water bath. Duration: 5 minutes.
# - Milestone: minute 55. Step: Rinse brown rice under cold water and start cooking it in the rice cooker according to the manufacturer's instructions. Duration: 5 minutes.
# - Milestone: minute 55. Step: Once the tofu is done, remove it from the oven and set aside. Duration: 5 minutes.
# - Milestone: minute 60. Step: After 1 hour of sous vide cooking, remove the chicken from the water bath, pat dry, and sear in a hot pan for 1-2 minutes on each side for a golden crust. Duration: 10 minutes.
# - Milestone: minute 70. Step: Slice the chicken breasts and assemble the sandwiches with lettuce and pickles in the whole grain rolls. Duration: 10 minutes.
# - Milestone: minute 80. Step: While the chicken is being seared, fill a large pot with water and bring it to a boil. Place the mixed vegetables in a steamer basket and steam for about 5-7 minutes until tender. Duration: 10 minutes.
# - Milestone: minute 90. Step: Slice the pork tenderloin and serve it over brown rice with steamed vegetables on the side. Drizzle with soy sauce if desired. Duration: 10 minutes.
# - Milestone: minute 100. Step: Pack the breakfast smoothie bowls, lunch sandwiches, and dinner portions into meal prep containers. Label and store all containers in the refrigerator for the week ahead. Duration: 15 minutes.
#
# This plan ensures that you maximize your time and equipment usage while minimizing the need for washing equipment between steps. Enjoy your meal prep!
